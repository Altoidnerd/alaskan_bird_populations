# %%
import pandas as pd
import numpy as np

# %%
effortdf = pd.DataFrame.from_csv('effort.csv')
weatherdf = pd.DataFrame.from_csv('weather.csv')
droughtdf = pd.DataFrame.from_csv('drought_fig-1.csv')
heavyPrecipdf = pd.DataFrame.from_csv('heavy-precip_fig-1.csv')
precipdf = pd.DataFrame.from_csv('precipitation_fig-1.csv')
temperaturedf = pd.DataFrame.from_csv('temperature_fig-1.csv')
bald_eagledf = pd.DataFrame.from_csv('bald_eagle_counts.csv')
chickadeedf = pd.DataFrame.from_csv('chickadee_counts.csv')
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: from_csv is deprecated. Please use read_csv(...) instead. Note that some of the default arguments are different, so please refer to the documentation for from_csv when changing your function calls
#   """Entry point for launching an IPython kernel.
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: FutureWarning: from_csv is deprecated. Please use read_csv(...) instead. Note that some of the default arguments are different, so please refer to the documentation for from_csv when changing your function calls
#
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: FutureWarning: from_csv is deprecated. Please use read_csv(...) instead. Note that some of the default arguments are different, so please refer to the documentation for from_csv when changing your function calls
#   This is separate from the ipykernel package so we can avoid doing imports until
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: FutureWarning: from_csv is deprecated. Please use read_csv(...) instead. Note that some of the default arguments are different, so please refer to the documentation for from_csv when changing your function calls
#   after removing the cwd from sys.path.
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:5: FutureWarning: from_csv is deprecated. Please use read_csv(...) instead. Note that some of the default arguments are different, so please refer to the documentation for from_csv when changing your function calls
#   """
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:6: FutureWarning: from_csv is deprecated. Please use read_csv(...) instead. Note that some of the default arguments are different, so please refer to the documentation for from_csv when changing your function calls
#
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: from_csv is deprecated. Please use read_csv(...) instead. Note that some of the default arguments are different, so please refer to the documentation for from_csv when changing your function calls
#   import sys
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:8: FutureWarning: from_csv is deprecated. Please use read_csv(...) instead. Note that some of the default arguments are different, so please refer to the documentation for from_csv when changing your function calls

# %%
weatherdf
# Out:
#             LowTemp  HighTemp        AMCloud       PMClouds   AMRain   PMRain  \
# CountYear3
# 118            27.0      34.0         Cloudy         Cloudy     None     None
# 117            25.0      36.0         Cloudy         Cloudy    Light     None
# 116            22.0      28.0  Partly Cloudy  Partly Cloudy     None     None
# 115            23.0      34.0         Cloudy         Cloudy    Light     None
# 114            14.0      25.0         Cloudy         Cloudy     None     None
# 113            -2.0      12.0          Clear          Clear     None     None
# 112            19.0      43.0  Partly Cloudy  Partly Cloudy     None     None
# 111           -10.0       5.0          Clear          Clear     None     None
# 110            -5.0       5.0         Cloudy         Cloudy     None     None
# 109            14.0      20.0  Partly Cloudy  Partly Cloudy     None     None
# 108            10.0      19.0  Partly Cloudy  Partly Cloudy     None     None
# 107             3.0      19.0         Cloudy         Cloudy     None     None
# 106            34.0      41.0  Partly Cloudy  Partly Cloudy     None     None
# 105            32.0      36.0         Cloudy         Cloudy     None    Light
# 104            18.0      30.0         Cloudy         Cloudy     None     None
# 103            21.0      29.0         Cloudy         Cloudy     None     None
# 102           -15.0      -1.0          Foggy          Foggy     None     None
# 101            15.0      27.0          Clear          Clear     None     None
# 100             3.0      13.0         Cloudy         Cloudy     None     None
# 99             19.0      24.0         Cloudy         Cloudy     None     None
# 98             12.0      20.0         Cloudy         Cloudy  Unknown  Unknown
# 97             11.0      27.0          Clear          Clear  Unknown  Unknown
# 96             21.0      28.0         Cloudy         Cloudy  Unknown  Unknown
# 95             11.0      18.0        Unknown        Unknown     None     None
# 94             28.0      37.0         Cloudy         Cloudy  Unknown  Unknown
# 93              0.0      14.0         Cloudy         Cloudy     None     None
# 92             24.0      32.0        Unknown        Unknown     None     None
# 91             -2.0       7.0         Cloudy         Cloudy  Unknown  Unknown
# 90             29.0      34.0          Foggy          Foggy  Unknown  Unknown
# 89             25.0      34.0         Cloudy         Cloudy  Unknown  Unknown
# 88             20.0      38.0         Cloudy         Cloudy     None    Light
# 87             30.0      33.0  Partly Cloudy  Partly Cloudy  Unknown  Unknown
# 86             35.0      42.0         Cloudy         Cloudy    Light    Light
# 85              9.0      14.0          Foggy          Foggy     None     None
# 84             10.0      23.0         Cloudy         Cloudy  Unknown  Unknown
# 83              8.0      23.0  Partly Cloudy  Partly Cloudy  Unknown  Unknown
# 82             20.0      28.0  Partly Cloudy  Partly Cloudy  Unknown  Unknown
# 81            -18.0       5.0          Clear          Clear  Unknown  Unknown
# 80            -10.0       5.0          Clear          Clear  Unknown  Unknown
# 72             28.0      30.0          Foggy          Foggy     None     None
# 71            -13.0      -2.0          Clear          Clear     None     None
# 70             26.0      42.0         Cloudy         Cloudy    Light    Light
# 69             -8.0      10.0          Foggy          Foggy     None     None
# 68             -3.0       8.0         Cloudy         Cloudy     None     None
# 67              5.0      23.0          Clear          Clear  Unknown  Unknown
# 66              8.0      14.0          Clear          Clear  Unknown  Unknown
# 64             15.0      24.0  Partly Cloudy  Partly Cloudy  Unknown  Unknown
# 63             22.0      34.0        Unknown        Unknown     None    Light
#
#              AMSnow   PMSnow
# CountYear3
# 118            None     None
# 117           Light     None
# 116            None     None
# 115           Light     None
# 114           Light    Heavy
# 113            None     None
# 112            None     None
# 111            None     None
# 110            None     None
# 109            None     None
# 108            None     None
# 107            None     None
# 106            None     None
# 105            None    Light
# 104            None     None
# 103            None     None
# 102            None     None
# 101            None     None
# 100            None     None
# 99             None     None
# 98          Unknown  Unknown
# 97          Unknown  Unknown
# 96          Unknown  Unknown
# 95            Heavy    Light
# 94          Unknown  Unknown
# 93            Light    Light
# 92            Heavy     None
# 91          Unknown  Unknown
# 90          Unknown  Unknown
# 89          Unknown  Unknown
# 88             None     None
# 87          Unknown  Unknown
# 86             None     None
# 85            Light     None
# 84          Unknown  Unknown
# 83          Unknown  Unknown
# 82          Unknown  Unknown
# 81          Unknown  Unknown
# 80          Unknown  Unknown
# 72             None     None
# 71             None     None
# 70             None     None
# 69            Light    Light
# 68            Light    Light
# 67          Unknown  Unknown
# 66          Unknown  Unknown
# 64          Unknown  Unknown
# 63            Light     None
